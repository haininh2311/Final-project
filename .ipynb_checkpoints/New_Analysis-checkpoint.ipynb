# %%
# %pip install matplotlib pandas numpy seaborn wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from datetime import datetime
from collections import Counter
import os

# %%
new_df = pd.read_csv('Data/langthanghanoiofficial_cleaned(new).csv')

# %% [markdown]
# Đây là dữ liệu mới thu thập được từ fanpage langthanghanoi bao gồm dữ liệu của 99 bài kể từ ngày 22-11-2023 đến ngày 27-11-2023.

# %%
old_df = pd.read_csv('Data/langthanghanoiofficial_cleaned.csv')

# %% [markdown]
# Đây là dữ liệu cũ

# %% [markdown]
# ## Tính trung bình số lượt 'likes', 'comments', và 'shares'

# %%
average_likes = new_df['likes'].mean()
average_comments = new_df['comments'].mean()
average_shares = new_df['shares'].mean()

# %% [markdown]
# Số lượt like trung bình mỗi bài

# %%
average_likes
# Out:
# 2868.96

# %% [markdown]
# Số lượt comments trung bình mỗi bài

# %%
average_comments
# Out:
# 1126.63

# %% [markdown]
# Số lượt shares trung bình mỗi bài

# %%
average_shares
# Out:
# 103.28

# %% [markdown]
# ## Sự biến đổi của số lượng reactions, shares, comments theo thời gian

# %%
new_df['time'] = pd.to_datetime(new_df['time'])
new_df['date'] = new_df['time'].dt.date

# %%
daily_summary = new_df.groupby('date').agg(
    total_reactions=('reaction_count', 'sum'),
    total_comments=('comments', 'sum'),
    total_shares=('shares', 'sum')
).reset_index()

# %%
plt.figure(figsize=(15, 6))
plt.plot(daily_summary['date'].astype(str), daily_summary['total_reactions'], label='Reactions', marker='o')
plt.plot(daily_summary['date'].astype(str), daily_summary['total_comments'], label='Comments', marker='x')
plt.plot(daily_summary['date'].astype(str), daily_summary['total_shares'], label='Shares', marker='^')

plt.title('Xu hướng reactions, comments, shares hằng ngày (22/11/2023 - 27/11/2023)')
plt.xlabel('Date')
plt.ylabel('Total Count')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Lượt tương tác theo thời gian

# %%
new_df['total_interactions'] = new_df['likes'] + new_df['comments'] + new_df['shares']
new_df.set_index('time')['total_interactions'].plot()
# Out:
# <Axes: xlabel='time'>
