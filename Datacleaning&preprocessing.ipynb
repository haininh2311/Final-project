# %% [markdown]
# ## Install the required library

# %%
# %pip install matplotlib pandas numpy seaborn wordcloud
# Out:
# Requirement already satisfied: matplotlib in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (3.7.2)
# Requirement already satisfied: pandas in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (2.1.0)
# Requirement already satisfied: numpy in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (1.25.2)
# Requirement already satisfied: seaborn in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (0.13.0)
# Requirement already satisfied: wordcloud in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (1.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\tanphat\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read and check data

# %%
raw_df = pd.read_csv('Data/langthanghanoiofficial.csv')
new_df = pd.read_csv('Data/langthanghanoiofficial(new).csv')
#print(new_df.info())
print(raw_df.isnull().sum())
# Out:
# post_id                            0
# text                               0
# post_text                          0
# shared_text                       94
# original_text                     78
# time                               0
# timestamp                          0
# image                             26
# image_lowquality                   8
# images                             0
# images_description                 0
# images_lowquality                  0
# images_lowquality_description      0
# video                            100
# video_duration_seconds           100
# video_height                     100
# video_id                         100
# video_quality                    100
# video_size_MB                    100
# video_thumbnail                  100
# video_watches                    100
# video_width                      100
# likes                              0
# comments                           0
# shares                             0
# post_url                           0
# link                              99
# links                              0
# user_id                            0
# username                           0
# user_url                           0
# is_live                            0
# factcheck                        100
# shared_post_id                    94
# shared_time                       94
# shared_user_id                    94
# shared_username                   94
# shared_post_url                   94
# available                          0
# comments_full                      0
# reactors                          66
# w3_fb_url                         66
# reactions                         66
# reaction_count                     0
# with                              94
# page_id                            0
# sharers                          100
# image_id                          68
# image_ids                          0
# video_ids                         55
# videos                            55
# was_live                           0
# fetched_time                      66
# dtype: int64

# %% [markdown]
# ## Data cleaning

# %%
# Loại bỏ các cột với số lượng lớn giá trị thiếu
columns_to_drop = ['video', 'video_duration_seconds', 'video_height', 'video_id', 'video_quality', 
                   'video_size_MB', 'video_thumbnail', 'video_watches', 'video_width', 'factcheck', 'sharers']
# Loại bỏ cột không cần thiết
irrelevant_columns = ['image', 'image_lowquality', 'images', 'video_ids', 'videos', 'image_id', 'image_ids', 'was_live']

raw_df = raw_df.drop(columns=irrelevant_columns)
raw_df = raw_df.drop(columns=columns_to_drop)

columns_to_drop = [col for col in columns_to_drop if col in new_df.columns]
irrelevant_columns = [col for col in irrelevant_columns if col in new_df.columns]

new_df = new_df.drop(columns=irrelevant_columns)
new_df = new_df.drop(columns=columns_to_drop)

# %%
# Xử lý các cột có giá trị thiếu còn lại
# Đối với 'shared_text', 'original_text', và các cột tương tự, điền vào 'Không có' nếu giá trị là NaN
text_columns_with_nulls = ['shared_text', 'original_text', 'reactors', 'w3_fb_url', 'reactions', 
                           'with', 'fetched_time']
for col in text_columns_with_nulls:
    raw_df[col].fillna('Không có', inplace=True)
    new_df[col].fillna('Không có', inplace=True)

# %% [markdown]
# ## Data Preprocessing

# %%
# Chuyển đổi cột 'timestamp' thành datetime
raw_df['time'] = pd.to_datetime(raw_df['timestamp'], unit='s')
new_df['time'] = pd.to_datetime(new_df['timestamp'], unit='s')

# %% [markdown]
# ## Export cleaned data

# %%
# Xuất dữ liệu đã xử lý
raw_df.to_csv('Data/langthanghanoiofficial_cleaned.csv', index=False)
new_df.to_csv('Data/langthanghanoiofficial_cleaned(new).csv', index=False)
new_df.head()  # Hiển thị một số hàng đầu tiên của DataFrame đã được làm sạch
#raw_df.info()
# Out:
#            post_id                                               text  \
# 0  651992230442287  Bạn có biết cô đơn là gì không?\n\nCo...
# 1  651976497110527                          Hôm nay của cậu thế nào ?
# 2  651954307112746  HỒ TÂY LÚC NÀY ‼️\n\nBAO LÂU RỒI BẠN CHƯA ĐI H...
# 3  651926453782198  Hà Nội đẹp nhất về đêm, người thông thái nhất ...
# 4  651902207117956  Nếu Noel này bạn ko đi chơi thì là do bạn ko c...
#
#                                            post_text shared_text  \
# 0  Bạn có biết cô đơn là gì không?\n\nCo...    Không có
# 1                          Hôm nay của cậu thế nào ?    Không có
# 2  HỒ TÂY LÚC NÀY ‼️\n\nBAO LÂU RỒI BẠN CHƯA ĐI H...    Không có
# 3  Hà Nội đẹp nhất về đêm, người thông thái nhất ...    Không có
# 4  Nếu Noel này bạn ko đi chơi thì là do bạn ko c...    Không có
#
#   original_text                time   timestamp  \
# 0      Không có 2023-11-27 15:49:29  1701100169
# 1      Không có 2023-11-27 15:12:37  1701097957
# 2      Không có 2023-11-27 14:22:09  1701094929
# 3      Không có 2023-11-27 13:19:22  1701091162
# 4      Không có 2023-11-27 12:20:39  1701087639
#
#                                   images_description  \
# 0  ['May be an image of 2 people, twilight and cl...
# 1                                                 []
# 2  ['May be an image of boat', 'May be an image o...
# 3  ["May be an image of 2 people and text that sa...
# 4                                                 []
#
#                                    images_lowquality  \
# 0  ['https://scontent.fhan15-1.fna.fbcdn.net/v/t3...
# 1  ['https://scontent.fhan5-6.fna.fbcdn.net/v/t39...
# 2  ['https://scontent.fhan15-2.fna.fbcdn.net/v/t3...
# 3  ['https://scontent.fhan5-6.fna.fbcdn.net/v/t39...
# 4  ['https://scontent.fhan5-8.fna.fbcdn.net/m1/v/...
#
#                        images_lowquality_description  ...  shared_post_url  \
# 0  ['May be an image of 2 people, twilight and cl...  ...              NaN
# 1  ['May be an image of 6 people, scooter, street...  ...              NaN
# 2  ['May be an image of boat', 'May be an image o...  ...              NaN
# 3  ["May be an image of 2 people and text that sa...  ...              NaN
# 4                            ['Like', 'Haha', 'Sad']  ...              NaN
#
#    available                                      comments_full  \
# 0       True  [{'comment_id': '660886112903664', 'comment_ur...
# 1       True  [{'comment_id': '882263090182152', 'comment_ur...
# 2       True  [{'comment_id': '866995745042725', 'comment_ur...
# 3       True  [{'comment_id': '1033780314335674', 'comment_u...
# 4       True  [{'comment_id': '889246526225344', 'comment_ur...
#
#                                             reactors  \
# 0                                                 []
# 1  [{'name': 'Nguyễn Sơn', 'link': 'https://faceb...
# 2  [{'name': 'Nga Nguyễn', 'link': 'https://faceb...
# 3  [{'name': 'Hứa Văn Cường', 'link': 'https://fa...
# 4  [{'name': 'Phan Văn Sáu', 'link': 'https://fac...
#
#                                            w3_fb_url  \
# 0  https://www.facebook.com/langthanghanoiofficia...
# 1  https://www.facebook.com/langthanghanoiofficia...
# 2  https://www.facebook.com/langthanghanoiofficia...
# 3  https://www.facebook.com/langthanghanoiofficia...
# 4  https://www.facebook.com/langthanghanoiofficia...
#
#                                            reactions  reaction_count  \
# 0  {'like': 1682, 'love': 189, 'haha': 23, 'wow':...            1959
# 1  {'like': 3504, 'love': 76, 'haha': 56, 'wow': ...            3988
# 2  {'like': 2249, 'love': 50, 'haha': 26, 'wow': ...            2346
# 3               {'like': 667, 'love': 1, 'haha': 10}             678
# 4  {'like': 1282, 'love': 10, 'haha': 311, 'wow':...            1663
#
#        with           page_id                fetched_time
# 0  Không có  2425534324394516  2023-11-27 23:19:09.657332
# 1  Không có  2425534324394516  2023-11-27 23:19:17.656312
# 2  Không có  2425534324394516  2023-11-27 23:19:55.051841
# 3  Không có  2425534324394516  2023-11-27 23:20:05.144687
# 4  Không có  2425534324394516  2023-11-27 23:20:07.955732
#
# [5 rows x 34 columns]
